# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from datetime import timedelta
# if using a Jupyter notebook, includue:
# %matplotlib inline

import sys

# %%
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/customers.csv")
print(data.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data["Income"] = data[["Annual Income (k$)"]]
data["Spending"] = data[["Spending Score (1-100)"]]
data = data[["Income", "Spending"]]
print(data.head())
# Out:
#    Income  Spending
# 0      15        39
# 1      15        81
# 2      16         6
# 3      16        77
# 4      17        40

# %%
from sklearn.cluster import MeanShift
model = MeanShift(bandwidth=10)
model.fit(data)
pred = model.fit_predict(data)
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(12, 10))
plt.scatter(data["Income"], data["Spending"], c=pred, cmap='rainbow', alpha=0.9)
plt.show()

# %%
df = pd.read_csv('fishdata.csv',encoding= 'unicode_escape')
df.head()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      Year  Month  Day  hour  minute  second carbon monoxide  \
# 0  2020.0    6.0   18    14    59.0     8.0             199
# 1  2020.0    6.0   18    14    59.0    13.0             199
# 2  2020.0    6.0   18    14    59.0    18.0             199
# 3  2020.0    6.0   18    14    59.0    28.0             200
# 4  2020.0    6.0   18    14    59.0    33.0             200
#
#    external temperature  PM 2.5  external temp  humidity  internal temperature
# 0                  28.0    28.0           95.0     27.25                  4.39
# 1                  28.0    28.0           95.0     27.25                  4.38
# 2                  27.0    28.0           95.0     27.25                  4.42
# 3                  26.0    28.0           95.0     27.25                  4.39
# 4                  27.0    28.0           95.0     27.25                  4.42

# %%
df.rename(columns={'2020':'Year', '6':'Month', '18':'Day', '14':'Hour', '30':'Minute', '33':'Second',
       'qCBrs9¥ †R! „Â¤‡cäÍFóInitializing.... Please Wait!':'Carbonmonoxide', 'Unnamed: 7':'PM2.5',
       'Unnamed: 8':'External_Temp', 'Unnamed: 9':'Humidity', 'Unnamed: 10':'Internal_Temp', 'Unnamed: 11':'Ignore'
},inplace = True)

# %%
pd.reset_option('display.float_format')
pd.options.display.float_format = '{:.2f}'.format

# %%
df.dropna(inplace=True)

# %%
df2 = df[0:40000]

# %%
from sklearn.cluster import MeanShift
model = MeanShift(bandwidth=5)
model.fit(df2)
pred = model.fit_predict(df2)
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(12, 10))
plt.scatter(df2["External_Temp"], df2["Humidity"], c=pred, cmap='plasma', alpha=0.9)
plt.show()

# %%
from sklearn.cluster import MeanShift
model = MeanShift(bandwidth=10)
model.fit(df2)
pred = model.fit_predict(df2)
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(12, 10))
plt.scatter(df2["External_Temp"], df2["Humidity"], c=pred, cmap='plasma', alpha=0.9)
plt.show()

# %%
#Q2. Take Internal, external temperatures and humidity data and visualize them using 3D scatter plot and wireframe. Visualize using different color maps scatter plot surface plot wireframe

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')
# Data for three-dimensional scattered points
ax.scatter(df['Internal_Temp'], df['External_Temp'], df['Humidity'], c=df['Humidity'], cmap='winter');
ax.set_xlabel('Internal Temp')
ax.set_ylabel('External Temp')
ax.set_zlabel('Humidity')

plt.show()

# %%
ax.view_init(60, 40)
fig

# %%
x = df['Internal_Temp'].to_numpy()
y = df['External_Temp'].to_numpy()

# %%
X, Y = np.meshgrid(x[0:1000], y[0:1000])

# %%
df1 = pd.DataFrame(df, columns = ['Humidity'])
print(df1)

# %%
arr = df1.to_numpy()

# %%
datas= np.array([arr])
datas.resize((1000,1000))

# %%
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, datas, cmap='winter')
ax.set_xlabel('Internal Temp')
ax.set_ylabel('External Temp')
ax.set_zlabel('Humidity')
#ax.view_init(40, 45)
plt.show()

# %%
fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.plot_wireframe(X, Y, datas, color ='green')
ax.set_xlabel('Internal Temp')
ax.set_ylabel('External Temp')
ax.set_zlabel('Humidity')

plt.show()
